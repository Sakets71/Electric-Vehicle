# %%
# Cell 1: Import libraries & create folder structure
import pandas as pd
import os

# Make sure raw data folder exists
os.makedirs(r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw", exist_ok=True)

print("✅ Folder structure ready. Raw datasets will be stored in ../data/raw/")
# Out:
# ✅ Folder structure ready. Raw datasets will be stored in ../data/raw/

# %%
# Cell 2: Load EV Sales Data
ev_path = r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/EV_sales.csv"   # update path if file is in a different location

try:
    ev_sales = pd.read_csv(ev_path)
    print("✅ EV Sales dataset loaded successfully")
except Exception as e:
    print(f"❌ Error loading EV Sales: {e}")

ev_sales.head()
# Out:
# ✅ EV Sales dataset loaded successfully
#       Entity Code  Year  Share of new cars that are electric
# 0  Australia  AUS  2011                               0.0061
# 1  Australia  AUS  2012                               0.0290
# 2  Australia  AUS  2013                               0.0330
# 3  Australia  AUS  2014                               0.1500
# 4  Australia  AUS  2015                               0.1900

# %%
# Cell 3: Inspect EV Sales Data
print(ev_sales.info())
print(ev_sales.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Entity                               492 non-null    object
#  1   Code                                 447 non-null    object
#  2   Year                                 492 non-null    int64
#  3   Share of new cars that are electric  492 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 15.5+ KB
# None
#         Entity Code         Year  Share of new cars that are electric
# count      492  447   492.000000                           492.000000
# unique      34   31          NaN                                  NaN
# top     Brazil  BEL          NaN                                  NaN
# freq        15   15          NaN                                  NaN
# ...

# %%
# Cell 4: Save Raw Copy
ev_sales.to_csv(r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/ev_sales.csv", index=False)
print("✅ EV Sales data saved to data/raw/ev_sales.csv")
# Out:
# ✅ EV Sales data saved to data/raw/ev_sales.csv

# %%
# Cell 5: Load Charging Stations Data
charging_path = r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/charging_stations.csv"   # update path if needed

try:
    charging = pd.read_csv(charging_path)
    print("✅ Charging Stations dataset loaded successfully")
except Exception as e:
    print(f"❌ Error loading Charging Stations: {e}")

charging.head()
# Out:
# ✅ Charging Stations dataset loaded successfully
#                                    the_geom  GIS Object ID  \
# 0  POINT (-76.593139599729 39.273002600332)            432
# 1  POINT (-76.358197400357 39.522557499946)            415
# 2  POINT (-77.015387000118 38.785151000271)            723
# 3   POINT (-75.57589999961 38.392140000006)            430
# 4  POINT (-77.122977399738 39.059595500173)            475
#
#   Alternative Fuel Type                  Station Name         Street Address  \
# 0                  ELEC                  UNDER ARMOUR         1450 Beason St
# 1                  ELEC                BMW OF BEL AIR          716 Belair Rd
# 2                  ELEC  National Harbor Fleet Garage    150 Potomac Passage
# 3                  ELEC    Pohanka Nissan - Salisbury  2012 N Salisbury Blvd
# 4                  ELEC           1801 Rockville Pike    1801 Rockville Pike
#
#              Intersection Information       City State  ZIP Code  \
# ...

# %%
# Cell 6: Inspect Charging Stations Data
print(charging.info())
print(charging.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 40 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   the_geom                                  466 non-null    object
#  1   GIS Object ID                             466 non-null    int64
#  2   Alternative Fuel Type                     466 non-null    object
#  3   Station Name                              466 non-null    object
#  4   Street Address                            466 non-null    object
#  5   Intersection Information                  220 non-null    object
#  6   City                                      466 non-null    object
#  7   State                                     466 non-null    object
#  8   ZIP Code                                  466 non-null    int64
#  9   ZIP Plus4 Information                     0 non-null      float64
# ...

# %%
# Cell 7: Save Raw Copy
charging.to_csv(r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/charging.csv", index=False)
print("✅ Charging data saved to data/raw/charging.csv")
# Out:
# ✅ Charging data saved to data/raw/charging.csv

# %%
# Cell 8: Load GDP/Population Data
gdp_path = r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/gdp_data.csv"   # update path if needed

try:
    gdp = pd.read_csv(gdp_path)
    print("✅ GDP/Population dataset loaded successfully")
except Exception as e:
    print(f"❌ Error loading GDP data: {e}")

gdp.head()
# Out:
# ✅ GDP/Population dataset loaded successfully
#         Entity Code   Year  Population (historical)
# 0  Afghanistan  AFG -10000                    14737
# 1  Afghanistan  AFG  -9000                    20405
# 2  Afghanistan  AFG  -8000                    28253
# 3  Afghanistan  AFG  -7000                    39120
# 4  Afghanistan  AFG  -6000                    54166

# %%
# Cell 9: Inspect GDP/Population Data
print(gdp.info())
print(gdp.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58890 entries, 0 to 58889
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entity                   58890 non-null  object
#  1   Code                     55501 non-null  object
#  2   Year                     58890 non-null  int64
#  3   Population (historical)  58890 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 1.8+ MB
# None
#           Entity   Code          Year  Population (historical)
# count      58890  55501  58890.000000             5.889000e+04
# unique       268    250           NaN                      NaN
# top     Zimbabwe    AFG           NaN                      NaN
# freq         261    261           NaN                      NaN
# mean         NaN    NaN   1612.646001             5.086084e+07
# std          NaN    NaN   1402.986856             3.002681e+08
# ...

# %%
# Cell 10: Save Raw Copy
gdp.to_csv(r"C:\Users\Saket\OneDrive\Desktop\4th sem\python\EDA\EV_Market_Analysis\data\raw/gdp.csv", index=False)
print("✅ GDP data saved to data/raw/gdp.csv")
# Out:
# ✅ GDP data saved to data/raw/gdp.csv

# %%
# Cell 11: Summary of Day 1
print("📊 Summary:")
print(f"EV Sales shape: {ev_sales.shape}")
print(f"Charging shape: {charging.shape}")
print(f"GDP shape: {gdp.shape}")

print("\n✅ Day 1 setup complete! All raw datasets are stored in ../data/raw/")
# Out:
# 📊 Summary:
# EV Sales shape: (492, 4)
# Charging shape: (466, 40)
# GDP shape: (58890, 4)
#
# ✅ Day 1 setup complete! All raw datasets are stored in ../data/raw/
